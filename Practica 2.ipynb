# %% [markdown]
# #Genomica Computacional
# ## Práctica 2: Herramientas bioinformaticas (Phyton)

# %% [markdown]
# #Parte 1: Escribir un programa que me permita aplicar el 10% de descuento si la compra total es mayor a $100

# %%
#Si la compra es mayor a $100, aplica 10% de descuento.
#Si la comora es menor a $100, no aplica 10% de descuento.

Compra=378 

if Compra <=100:
    print('no aplica el 10% de descuento')
else:
    print('aplica el 10% de descuento')
# Out:
# aplica el 10% de descuento

# %% [markdown]
# #Parte2:  Sabiendo que la fórmula para obtener el área de un triángulo es a = (b x h) / 2, donde b es la longitud de la base del triángulo, y h es su altura. Escribir un programa que permita realizar el cálculo del área de un triángulo. Si el área contiene valores decimales, imprimir el resultado con dos dígitos.

# %%
b= 8.7
h= 5.5

# %%
a= b * h / 2

# %%
print (a)
# Out:
# 23.924999999999997

# %%
round (a, 2)
# Out:
# 23.92

# %% [markdown]
# #La fórmula para el Índice de Masa Corportal es IMC = kg/m2 donde kg es el peso de la persona en kilogramos y m2 es la altura en metros al cuadrado. Realizar un programa que calcula el IMC cuando se le provee el peso y la altura.

# %%
kg= 70
m= 1.65

# %%
IMC= kg / m ** 2

# %%
print(IMC)
# Out:
# 25.71166207529844

# %%
round (IMC, 1)
# Out:
# 25.7
